# %% [markdown]
# <a href="https://colab.research.google.com/github/Kushu06/DS_LAB/blob/main/Exp_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#4A
import pandas as pd
import numpy as np
data=pd.Series(np.random.randn(6),index=[['a','a','b','b','c','c'],[1,2,1,2,1,2]])
print(data)
print(data['b'])
print(data[:,1])
# Out:
# a  1   -0.945866
#    2    0.846207
# b  1   -0.243720
#    2   -0.002677
# c  1   -0.488684
#    2   -0.017749
# dtype: float64
# 1   -0.243720
# 2   -0.002677
# dtype: float64
# a   -0.945866
# b   -0.243720
# c   -0.488684
# dtype: float64

# %%
#4B
df=data.unstack();
print(df);
print(df.stack())
# Out:
#           1         2
# a -0.945866  0.846207
# b -0.243720 -0.002677
# c -0.488684 -0.017749
# a  1   -0.945866
#    2    0.846207
# b  1   -0.243720
#    2   -0.002677
# c  1   -0.488684
#    2   -0.017749
# dtype: float64

# %%
#4C
df1=pd.DataFrame({'a':[1,np.nan,3],'b':[4,5,6,]})
df2=pd.DataFrame({'a':[7,8,9],'b':[np.nan,11,12]})
merged=df1.combine_first(df2)
print(merged)
# Out:
#      a    b
# 0  1.0  4.0
# 1  8.0  5.0
# 2  3.0  6.0
